# %% [markdown]
# # Optical Character Recognition

# %%
# %pip3 install torch torchvision torchaudio
# %pip install easyocr
# %pip install opencv-python-headless # For image processing

# Download our test image
# !wget -q https://upload.wikimedia.org/wikipedia/commons/f/f9/Road.sign.arp.750pix.jpg
# Out:
# Found existing installation: torch 2.5.1
# Uninstalling torch-2.5.1:
#   Successfully uninstalled torch-2.5.1
# WARNING: Skipping torchvision as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# ...
# Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 38.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.8 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 1.5 MB/s eta 0:00:00:00:01
# ...
